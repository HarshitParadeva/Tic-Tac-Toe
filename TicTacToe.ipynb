# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshitParadeva/Tic-Tac-Toe/blob/main/TicTacToe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def print_board(board):
    print("-------------")
    for i in range(3):
        print("|", board[i*3], "|", board[i*3 + 1], "|", board[i*3 + 2], "|")
        print("-------------")

def check_win(board, player):
    for i in range(3):
        if all(board[i*3 + j] == player for j in range(3)):
            return True
        if all(board[j*3 + i] == player for j in range(3)):
            return True
    if all(board[i*4] == player for i in range(3)):
        return True
    if all(board[i*2+2] == player for i in range(3)):
        return True
    return False

def check_draw(board):
    return all(cell != ' ' for cell in board)

def play_tic_tac_toe():
    player1 = input("Enter name of Player 1 (X): ")
    player2 = input("Enter name of Player 2 (O): ")
    board = [' '] * 9
    players = {'X': f'\033[91mX\033[0m', 'O': f'\033[92mO\033[0m'}  # Red for X, Green for O
    names = {'X': player1, 'O': player2}
    turn = 0

    while True:
        print_board(board)
        move = int(input(f"{names[list(players.keys())[turn % 2]]}, enter your move (1-9): ")) - 1

        if 0 <= move <= 8 and board[move] == ' ':
            board[move] = players[list(players.keys())[turn % 2]]
        else:
            print("Invalid move. Try again.")
            continue

        if check_win(board, players[list(players.keys())[turn % 2]]):
            print_board(board)
            print(f"Congratulations {names[list(players.keys())[turn % 2]]}! You win!")
            break
        elif check_draw(board):
            print_board(board)
            print("It's a draw!")
            break
        else:
            turn += 1

if __name__ == "__main__":
    play_tic_tac_toe()
# Out:
# Enter name of Player 1 (X): Harshit
# Enter name of Player 2 (O): Sujal
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
# Harshit, enter your move (1-9): 1
# -------------
# | X |   |   |
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
# Sujal, enter your move (1-9): 4
# -------------
# | X |   |   |
# -------------
# | O |   |   |
# -------------
# |   |   |   |
# -------------
# Harshit, enter your move (1-9): 2
# -------------
# | X | X |   |
# -------------
# | O |   |   |
# -------------
# |   |   |   |
# -------------
# Sujal, enter your move (1-9): 5
# -------------
# | X | X |   |
# -------------
# | O | O |   |
# -------------
# |   |   |   |
# -------------
# Harshit, enter your move (1-9): 7
# -------------
# | X | X |   |
# -------------
# | O | O |   |
# -------------
# | X |   |   |
# -------------
# Sujal, enter your move (1-9): 8
# -------------
# | X | X |   |
# -------------
# | O | O |   |
# -------------
# | X | O |   |
# -------------
# Harshit, enter your move (1-9): 9
# -------------
# | X | X |   |
# -------------
# | O | O |   |
# -------------
# | X | O | X |
# -------------
# Sujal, enter your move (1-9): 3
# -------------
# | X | X | O |
# -------------
# | O | O |   |
# -------------
# | X | O | X |
# -------------
# Harshit, enter your move (1-9): 6
# -------------
# | X | X | O |
# -------------
# | O | O | X |
# -------------
# | X | O | X |
# -------------
# It's a draw!
